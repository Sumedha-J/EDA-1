# %%
pip install flask==2.2.2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip freeze
# Out:
# absl-py==2.0.0
# aiobotocore @ file:///private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_b3e4znaej2/croot/aiobotocore_1680004294920/work
# aiofiles @ file:///private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_0ar7qj9rcj/croot/aiofiles_1683773588297/work
# aiohttp @ file:///Users/ec2-user/ci_py311/aiohttp_1678323186748/work
# aioitertools @ file:///tmp/build/80754af9/aioitertools_1607109665762/work
# aiosignal @ file:///tmp/build/80754af9/aiosignal_1637843061372/work
# aiosqlite @ file:///private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_13w97vul7u/croot/aiosqlite_1683773912122/work
# alabaster @ file:///home/ktietz/src/ci/alabaster_1611921544520/work
# anaconda-catalogs @ file:///private/var/folders/sy/f16zz6x50xz3113nwtb9bvq00000gp/T/abs_737qok84ed/croot/anaconda-catalogs_1685727302903/work
# anaconda-client==1.12.0
# anaconda-navigator==2.4.2
# anaconda-project @ file:///Users/ec2-user/ci_py311/anaconda-project_1678395481364/work
# ...

# %%
#define the server
from flask import Flask #import request,render_template
app= Flask(__name__) #create an object of the Flask class as a web application with the name (provide name) and store it as app
#app=Flask('My web appication')

@app.route('/') #Use the app decorator @app to create the root URL “/“ When you do not specify a request, by default, Get is requested.
def hello():
    return {This is first Flask application} #this is a json message you can also give a normal string like  return "hello world"

# %%
flask --app server --debug run #Use the following command to run the server from the terminal
curl -X GET -i -w '\n' localhost:5000 #You should now be able to use the CURL command on localhost:5000/ execute in shell

# %%
#Give Meaningful Names to Your Photos with IMG Captioning AI
# installing required libraries in my_env
pip install langchain==0.1.11 gradio==4.21.0 transformers==4.38.2 bs4==0.0.2 requests==2.31.0 torch==2.2.1

# %%
#Hugging Face Transformers is its support for multimodal learning, which combines text and image data for tasks such as image captioning and visual question answering.
#install transformers 
pip install transformers
# Out:
#   Cell In[3], line 3
#     pip install transformers
#         ^
# SyntaxError: invalid syntax

# %%
#Bootstrapping Language-Image Pre-training (BLIP) model can perform various multi-modal tasks, 
#including image-text retrieval and image captioning

# Install the transformers library
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image

# Initialize the processor and model from Hugging Face
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# Load an image
image = Image.open("/Users/sumedhajauhari/Downloads/Beautiful_Red_Rose.jpg")

# Prepare the image
inputs = processor(image, return_tensors="pt")

# Generate captions
outputs = model.generate(**inputs)
caption = processor.decode(outputs[0],skip_special_tokens=True)
 
print("Generated Caption:", caption)
# Out:
# /Users/sumedhajauhari/anaconda3/lib/python3.11/site-packages/transformers/generation/utils.py:1353: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Generated Caption: a red rose with green leaves in the background

# %%
pip install gradio
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 23.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 14.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.8/857.8 kB 14.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.9/388.9 kB 9.9 MB/s eta 0:00:00ta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.6/250.6 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 22.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 4.1 MB/s eta 0:00:00
# ...

# %%
import gradio as gr

def greet(name, intensity):
  return "Hello, " + name + "!" * int(intensity)
demo = gr.Interface(
  fn=greet,
  inputs=["text", "slider"],
  outputs=["text"],
)
#Gradio includes more than 30 built-in components (such as the gr.Textbox(), gr.Image(), and gr.HTML() components) that are designed for machine learning applications.
demo.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7861
# IMPORTANT: You are using gradio version 4.27.0, however version 4.29.0 is available, please upgrade.
# --------
# Running on public URL: https://5e5f16beea4d806796.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://5e5f16beea4d806796.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
pip install transformers==4.30.2 torch
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.6/113.6 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 17.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.8/150.8 MB 13.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 17.4 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.14.1
#     Uninstalling tokenizers-0.14.1:
#       Successfully uninstalled tokenizers-0.14.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.34.1
#     Uninstalling transformers-4.34.1:
#       Successfully uninstalled transformers-4.34.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# %%
#creating a simple chatbot which interacts with user (demo with print statements to understand step by step)
#this model is not good hence don't execute the code just read it for understanding

model_name = "facebook/blenderbot-400M-distill"
# Load model (download on first run and reference local installation for consequent runs)
# model is an instance of the class AutoModelForSeq2SeqLM, which allows you to interact with your chosen language model.
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
# tokenizer is an instance of the class AutoTokenizer, which optimizes your input and passes it to the language model efficiently. It does so by converting your text input to “tokens”, which is how the model interprets the text.
tokenizer = AutoTokenizer.from_pretrained(model_name)

# you need to initialize an object where you can store your conversation history.
#1. Initialize object to store conversation history
#2. Encode conversation history as a string
#3. Fetch prompt from user
#4. Tokenize (optimize) prompt
#5. Generate output from the model using prompt and history
#6. Decode output
#7. Update conversation history


conversation_history = [] #step1 we are creating a list to store history
history_string = "\n".join(conversation_history) #step2
input_text ="hello, how are you doing?" #step 3
inputs = tokenizer.encode_plus(history_string, input_text, return_tensors="pt") #step4
print("inputs=", inputs)

tokenizer.pretrained_vocab_files_map
outputs = model.generate(**inputs) #step5
print("outputs=", outputs)

response = tokenizer.decode(outputs[0], skip_special_tokens=True).strip() #step6
print("response=", response)

conversation_history.append(input_text) #step7
conversation_history.append(response)
print(conversation_history)

# %%
#save it in a python file and run from terminal

#Transformers and LLMs work together within a chatbot to enable conversation.
#A special program called a ‘transformer’ acts as the brain of the chatbot
#In a chatbot application, the back-end server will receive the prompts from the front-end interface and feed them to the chatbot, which will process the prompts
#Here we worked on creating a simple chatbot using Microsoft's DialoGPT-medium model and Hugging Face’s Python library, Transformers
from transformers import AutoModelForCausalLM, AutoTokenizer

# Load DialoGPT model and tokenizer
model_name = "microsoft/DialoGPT-medium"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# Define function to generate response from DialoGPT
def generate_response(prompt):
    input_ids = tokenizer.encode(prompt + tokenizer.eos_token, return_tensors="pt")
    response_ids = model.generate(input_ids, max_length=100, num_return_sequences=1, pad_token_id=tokenizer.eos_token_id)
    response = tokenizer.decode(response_ids[0], skip_special_tokens=True)
    return response

# Main loop for chatbot
while True:
    user_input = input("You: ")
    response = generate_response(user_input)
    print("ChatBot:", response[len(user_input):].strip())
